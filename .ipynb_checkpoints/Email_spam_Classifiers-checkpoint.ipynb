# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('spam.csv', encoding='latin1')
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.shape
# Out:
# (5572, 5)

# %% [markdown]
# **Steps to do the projects**
#
# - data cleaning
#
# - EDA
#
# - Text preprocessing
#
# - Model Building
#
# - Evaluations
#
# - Improvements
#
# - Convert to a website
#
# - Deploy into a website

# %% [markdown]
# **Data cleaning**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %% [markdown]
# - In the above datasets we can see in columns 2, 3 and 4 there are less values are presents so, we remove these(2, 3, 4) columns

# %%
df.drop(columns=['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], inplace=True)

# %%
df.sample(5)
# Out:
#        v1                                                 v2
# 3168  ham                Haven't seen my facebook, huh? Lol!
# 1350  ham                             Bugis oso near wat...
# 4769  ham  CHEERS LOU! YEAH WAS A GOODNITE SHAME U NEVA C...
# 2562  ham               Yeah I am, so I'll leave maybe 7ish?
# 3716  ham                       I'm gonna rip out my uterus.

# %%
# renaming the columns
df.rename(columns={'v1':'target', 'v2':'text'}, inplace=True)
df.sample(5)
# Out:
#      target                                               text
# 4562    ham  Come around  &lt;DECIMAL&gt; pm vikky..i'm ots...
# 3221    ham  Hi, my love! How goes that day? Fuck, this mor...
# 1496    ham  I'm always on yahoo messenger now. Just send t...
# 1072   spam  Dear U've been invited to XCHAT. This is our f...
# 2400    ham            Hi! This is Roger from CL. How are you?

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
df['target'] = encoder.fit_transform(df['target'])

# %%
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
# Check missing values
df.isnull().sum()
# Out:
# target    0
# text      0
# dtype: int64

# %%
# check for the duplicates
df.duplicated().sum()
# Out:
# 403

# %%
# remove duplicates
df = df.drop_duplicates(keep='first')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (5169, 2)

# %% [markdown]
# **EDA**

# %% [markdown]
# - First we need to test how much **spam** and how much **ham** was present

# %%
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
df['target'].value_counts()
# Out:
# target
# 0    4516
# 1     653
# Name: count, dtype: int64

# %%
plt.pie(df['target'].value_counts(), labels=['ham', 'spam'], autopct="%0.2f")
plt.show()

# %%
pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# - First we need to check how much alphabets, words and sentences are used
#
# - we also create 3 columns i.e no. of character, words, sentences are present in SMS
#
# - For this we need to import a laibrary name is nltk(Natural Language Tool Kit)

# %% [markdown]
# - In the above pie chart we noticed that 88% will be ham
#
# - and also 13% will be spam
#
# - so it mentioned that data was inbalanced

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\kdeepak_new\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df['num_character'] = df['text'].apply(len)

# %%
df.head()
# Out:
#    target                                               text  num_character
# 0       0  Go until jurong point, crazy.. Available only ...            111
# 1       0                      Ok lar... Joking wif u oni...             29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...            155
# 3       0  U dun say so early hor... U c already then say...             49
# 4       0  Nah I don't think he goes to usf, he lives aro...             61

# %%
# No. of words
df['num_words'] = df['text'].apply(lambda x:len(nltk.word_tokenize(x)))

# %%
df.head()
# Out:
#    target                                               text  num_character  \
# 0       0  Go until jurong point, crazy.. Available only ...            111
# 1       0                      Ok lar... Joking wif u oni...             29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...            155
# 3       0  U dun say so early hor... U c already then say...             49
# 4       0  Nah I don't think he goes to usf, he lives aro...             61
#
#    num_words
# 0         24
# 1          8
# 2         37
# 3         13
# 4         15

# %%
# no. of sentence
df['num_sentence'] = df['text'].apply(lambda x:len(nltk.sent_tokenize(x)))

# %%
df.head()
# Out:
#    target                                               text  num_character  \
# 0       0  Go until jurong point, crazy.. Available only ...            111
# 1       0                      Ok lar... Joking wif u oni...             29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...            155
# 3       0  U dun say so early hor... U c already then say...             49
# 4       0  Nah I don't think he goes to usf, he lives aro...             61
#
#    num_words  num_sentence
# 0         24             2
# 1          8             2
# 2         37             2
# 3         13             1
# 4         15             1

# %%
df[['num_character', 'num_words', 'num_sentence']].describe()
# Out:
#        num_character    num_words  num_sentence
# count    5169.000000  5169.000000   5169.000000
# mean       78.977945    18.455794      1.965564
# std        58.236293    13.324758      1.448541
# min         2.000000     1.000000      1.000000
# 25%        36.000000     9.000000      1.000000
# 50%        60.000000    15.000000      1.000000
# 75%       117.000000    26.000000      2.000000
# max       910.000000   220.000000     38.000000

# %%
# we divide ham and spam in different ways

# %% [markdown]
# **For ham messages**

# %%
df[df['target']==0][['num_character', 'num_words', 'num_sentence']].describe()
# Out:
#        num_character    num_words  num_sentence
# count    4516.000000  4516.000000   4516.000000
# mean       70.459256    17.123782      1.820195
# std        56.358207    13.493970      1.383657
# min         2.000000     1.000000      1.000000
# 25%        34.000000     8.000000      1.000000
# 50%        52.000000    13.000000      1.000000
# 75%        90.000000    22.000000      2.000000
# max       910.000000   220.000000     38.000000

# %% [markdown]
# **For spam messages**

# %%
df[df['target']==1][['num_character', 'num_words', 'num_sentence']].describe()
# Out:
#        num_character   num_words  num_sentence
# count     653.000000  653.000000    653.000000
# mean      137.891271   27.667688      2.970904
# std        30.137753    7.008418      1.488425
# min        13.000000    2.000000      1.000000
# 25%       132.000000   25.000000      2.000000
# 50%       149.000000   29.000000      3.000000
# 75%       157.000000   32.000000      4.000000
# max       224.000000   46.000000      9.000000

# %% [markdown]
# **ploting using histogram**

# %%
plt.figure(figsize=(10,6))
sns.histplot(df[df['target']==0]['num_character'])
sns.histplot(df[df['target']==1]['num_character'], color='black')
# Out:
# <Axes: xlabel='num_character', ylabel='Count'>

# %%
plt.figure(figsize=(10,6))
sns.histplot(df[df['target']==0]['num_words'])
sns.histplot(df[df['target']==1]['num_words'], color='black')
# Out:
# <Axes: xlabel='num_words', ylabel='Count'>

# %%
plt.figure(figsize=(10,6))
sns.histplot(df[df['target']==0]['num_sentence'])
sns.histplot(df[df['target']==1]['num_sentence'], color='black')
# Out:
# <Axes: xlabel='num_sentence', ylabel='Count'>

# %% [markdown]
# - Now we find the relations between no.of words with no.of sentences and also character as well for this we use pair plot

# %%
sns.pairplot(df, hue='target')

# %%
df_encoded = pd.get_dummies(df, drop_first=True) # 0ne-Hot Encoding
df_numeric = df_encoded.select_dtypes(include=['number'])

# %% [markdown]
# **Now find the correlations**

# %%
plt.figure(figsize=(10,6))
corr = df_numeric.corr()
sns.heatmap(corr, annot=True)
plt.show()

# %%
from nltk.corpus import stopwords
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %% [markdown]
# **Data preprocessing**
#
# - Lower case
#
# - Tokenizations( It involves breaking down a text into smaller units, called tokens)
#
# - removing special characters
#
# - Removing stop words and punctuations
#
# - stemming (reducing words to their base or root form like; dancing, danced it converts dance)

# %%
def transform_text(text):
    text = text.lower()
    text = nltk.word_tokenize(text)
    y = []
    for i in text:
        if i.isalnum():
            y.append(i)
            
    text = y[:] # if we clear y like this then output also cleared 
    y.clear()
    
    for i in text:
        if i not in stopwords.words('english') and i not in string.punctuation:
            y.append(i)
    text = y[:]
    y.clear()
    
    for i in text:
        y.append(ps.stem(i))
            
    return " ".join(y)

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\kdeepak_new\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Removing stop words
from nltk.corpus import stopwords
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
ps.stem('loved')
# Out:
# 'love'

# %%
transform_text('Okay name ur price as long as its legal! Wen can I pick them up? Y u ave x ams xx')
# Out:
# 'okay name ur price long legal wen pick u ave x am xx'

# %%
df.columns
# Out:
# Index(['target', 'text', 'num_character', 'num_words', 'num_sentence'], dtype='object')

# %%
df['text'][10]
# Out:
# "I'm gonna be home soon and i don't want to talk about this stuff anymore tonight, k? I've cried enough today."

# %%
df['transformed_text'] = df['text'].apply(transform_text)

# %%
df.head()
# Out:
#    target                                               text  num_character  \
# 0       0  Go until jurong point, crazy.. Available only ...            111
# 1       0                      Ok lar... Joking wif u oni...             29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...            155
# 3       0  U dun say so early hor... U c already then say...             49
# 4       0  Nah I don't think he goes to usf, he lives aro...             61
#
#    num_words  num_sentence                                   transformed_text
# 0         24             2  go jurong point crazi avail bugi n great world...
# 1          8             2                              ok lar joke wif u oni
# 2         37             2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13             1                u dun say earli hor u c alreadi say
# 4         15             1               nah think goe usf live around though

# %% [markdown]
# **Use word cloud**

# %%
pip install wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# **wordcloud for spam**

# %%
from wordcloud import WordCloud
wc = WordCloud(width=500, height=500,min_font_size=10, background_color='white')

# %%
spam_wc = wc.generate(df[df['target']==1]['transformed_text'].str.cat(sep=" "))

# %%
plt.figure(figsize=(10,6))
plt.imshow(spam_wc)

# %% [markdown]
# **wordcloud for ham**

# %%
ham_wc = wc.generate(df[df['target']==0]['transformed_text'].str.cat(sep=" "))

# %%
plt.figure(figsize=(10,6))
plt.imshow(ham_wc)

# %%
df.head()
# Out:
#    target                                               text  num_character  \
# 0       0  Go until jurong point, crazy.. Available only ...            111
# 1       0                      Ok lar... Joking wif u oni...             29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...            155
# 3       0  U dun say so early hor... U c already then say...             49
# 4       0  Nah I don't think he goes to usf, he lives aro...             61
#
#    num_words  num_sentence                                   transformed_text
# 0         24             2  go jurong point crazi avail bugi n great world...
# 1          8             2                              ok lar joke wif u oni
# 2         37             2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13             1                u dun say earli hor u c alreadi say
# 4         15             1               nah think goe usf live around though

# %% [markdown]
# **Now we find out top 30 or 50 words for ham as well as spam**

# %% [markdown]
# **Top 30 for spam**

# %%
spam_corpus = []
for msg in df[df['target']==1]['transformed_text'].tolist():
    for word in msg.split():
        spam_corpus.append(word)

spam_corpus
# Out:
# ['free',
#  'entri',
#  '2',
#  'wkli',
#  'comp',
#  'win',
#  'fa',
#  'cup',
#  'final',
#  'tkt',
#  '21st',
#  'may',
#  'text',
#  'fa',
#  '87121',
#  'receiv',
#  'entri',
#  'question',
#  'std',
#  'txt',
#  'rate',
#  'c',
#  'appli',
#  '08452810075over18',
#  'freemsg',
#  'hey',
#  'darl',
#  '3',
#  'week',
#  'word',
#  'back',
#  'like',
#  'fun',
#  'still',
#  'tb',
#  'ok',
#  'xxx',
#  'std',
#  'chg',
#  'send',
#  'rcv',
#  'winner',
#  'valu',
#  'network',
#  'custom',
#  'select',
#  'receivea',
#  'prize',
#  'reward',
#  'claim',
#  'call',
#  'claim',
#  'code',
#  'kl341',
#  'valid',
#  '12',
#  'hour',
#  'mobil',
#  '11',
#  'month',
#  'u',
#  'r',
#  'entitl',
#  'updat',
#  'latest',
#  'colour',
#  'mobil',
#  'camera',
#  'free',
#  'call',
#  'mobil',
#  'updat',
#  'co',
#  'free',
#  '08002986030',
#  'six',
#  'chanc',
#  'win',
#  'cash',
#  '100',
#  'pound',
#  'txt',
#  'csh11',
#  'send',
#  'cost',
#  '6day',
#  'tsandc',
#  'appli',
# ...

# %%
len(spam_corpus)
# Out:
# 9939

# %%
from collections import Counter
Counter(spam_corpus).most_common(30)
# Out:
# [('call', 320),
#  ('free', 191),
#  ('2', 155),
#  ('txt', 141),
#  ('text', 122),
#  ('u', 119),
#  ('ur', 119),
#  ('mobil', 114),
#  ('stop', 104),
#  ('repli', 103),
#  ('claim', 98),
#  ('4', 97),
#  ('prize', 82),
#  ('get', 74),
#  ('new', 64),
#  ('servic', 64),
#  ('tone', 63),
#  ('send', 60),
#  ('urgent', 57),
#  ('nokia', 57),
#  ('contact', 56),
#  ('award', 55),
#  ('phone', 52),
#  ('cash', 51),
#  ('pleas', 51),
#  ('week', 49),
#  ('win', 48),
#  ('c', 45),
#  ('collect', 45),
#  ('min', 45)]

# %%
most_common = Counter(spam_corpus).most_common(30)
df_common = pd.DataFrame(most_common, columns=['word', 'frequency'])
sns.barplot(x=df_common['word'], y=df_common['frequency'])
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **Top 30 for ham**

# %%
ham_corpus = []
for msg in df[df['target']==0]['transformed_text'].tolist():
    for word in msg.split():
        ham_corpus.append(word)

ham_corpus
# Out:
# ['go',
#  'jurong',
#  'point',
#  'crazi',
#  'avail',
#  'bugi',
#  'n',
#  'great',
#  'world',
#  'la',
#  'e',
#  'buffet',
#  'cine',
#  'got',
#  'amor',
#  'wat',
#  'ok',
#  'lar',
#  'joke',
#  'wif',
#  'u',
#  'oni',
#  'u',
#  'dun',
#  'say',
#  'earli',
#  'hor',
#  'u',
#  'c',
#  'alreadi',
#  'say',
#  'nah',
#  'think',
#  'goe',
#  'usf',
#  'live',
#  'around',
#  'though',
#  'even',
#  'brother',
#  'like',
#  'speak',
#  'treat',
#  'like',
#  'aid',
#  'patent',
#  'per',
#  'request',
#  'mell',
#  'oru',
#  'minnaminungint',
#  'nurungu',
#  'vettam',
#  'set',
#  'callertun',
#  'caller',
#  'press',
#  '9',
#  'copi',
#  'friend',
#  'callertun',
#  'gon',
#  'na',
#  'home',
#  'soon',
#  'want',
#  'talk',
#  'stuff',
#  'anymor',
#  'tonight',
#  'k',
#  'cri',
#  'enough',
#  'today',
#  'search',
#  'right',
#  'word',
#  'thank',
#  'breather',
#  'promis',
#  'wont',
#  'take',
#  'help',
#  'grant',
#  'fulfil',
#  'promis',
#  'wonder',
# ...

# %%
len(ham_corpus)
# Out:
# 35404

# %%
from collections import Counter
Counter(ham_corpus).most_common(30)
# Out:
# [('u', 883),
#  ('go', 404),
#  ('get', 349),
#  ('gt', 288),
#  ('lt', 287),
#  ('2', 284),
#  ('come', 275),
#  ('got', 236),
#  ('know', 236),
#  ('like', 234),
#  ('call', 233),
#  ('time', 219),
#  ('ok', 217),
#  ('love', 216),
#  ('good', 213),
#  ('want', 208),
#  ('ur', 197),
#  ('day', 190),
#  ('need', 170),
#  ('one', 165),
#  ('lor', 159),
#  ('4', 156),
#  ('home', 152),
#  ('think', 149),
#  ('see', 147),
#  ('take', 143),
#  ('still', 143),
#  ('da', 142),
#  ('tell', 133),
#  ('make', 129)]

# %%
most_common = Counter(ham_corpus).most_common(30)
df_common = pd.DataFrame(most_common, columns=['word', 'frequency'])
sns.barplot(x= df_common['word'], y=df_common['frequency'])
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# **Model Building**

# %% [markdown]
# **Using Naive Bayes Algorithms**

# %% [markdown]
# - after transforming the data our input is **transformed_text** and output is **target**
#
# - The target was in the form of numerical but transformed_text was in the form of text so.. we need to convert this(vectorise this)

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
cv = CountVectorizer()
tf = TfidfVectorizer(max_features=3000)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
X_text = tf.fit_transform(df['transformed_text']).toarray()
X_num = scaler.fit_transform(df['num_character'].values.reshape(-1,1))
X = np.hstack((X_text, X_num))

# %% [markdown]
# - we already created our own features(columns; like num_character,num_word, num_sentence)
#
# - we generally add or append the num_character in our input

# %% [markdown]
# - In the above output between 0 and 1 there also values are present in between them so we need to scale them

# %%
X.shape
# Out:
# (5169, 3001)

# %%
y = df['target'].values
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,
                                                y,
                                                test_size=0.2,
                                                random_state=1234)

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
gnb = GaussianNB()
mnb = MultinomialNB()
bnb = BernoulliNB()

# %%
gnb.fit(X_train, y_train)
y_pred1 = gnb.predict(X_test)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))
# Out:
# 0.8462282398452611
# [[759 137]
#  [ 22 116]]
# 0.45849802371541504

# %%
mnb.fit(X_train, y_train)
y_pred2 = mnb.predict(X_test)
print(accuracy_score(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
print(precision_score(y_test,y_pred2))
# Out:
# 0.97678916827853
# [[896   0]
#  [ 24 114]]
# 1.0

# %%
bnb.fit(X_train, y_train)
y_pred3 = bnb.predict(X_test)
print(accuracy_score(y_test,y_pred3))
print(confusion_matrix(y_test,y_pred3))
print(precision_score(y_test,y_pred3))
# Out:
# 0.9864603481624759
# [[895   1]
#  [ 13 125]]
# 0.9920634920634921

# %% [markdown]
# - For brtter precession we use **TfidfVectorizer** and **MultinomialNB**

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier

# %%
pip install xgboost
# Out:
# ...
#
# ...

# %%
svc = SVC(kernel='sigmoid', gamma=1.0)
knc = KNeighborsClassifier()
mnb = MultinomialNB()
dtc = DecisionTreeClassifier(max_depth=5)
lrc = LogisticRegression(solver='liblinear', penalty='l1')
rfc = RandomForestClassifier(n_estimators=50, random_state=2)
abc = AdaBoostClassifier(n_estimators=50, random_state=2)
bc = BaggingClassifier(n_estimators=50, random_state=2)
etc = ExtraTreesClassifier(n_estimators=50, random_state=2)
gbdt = GradientBoostingClassifier(n_estimators=50,random_state=2)
xgb = XGBClassifier(n_estimators=50,random_state=2)

# %%
clfs = {
    'SVC' : svc,
    'KN' : knc, 
    'NB': mnb, 
    'DT': dtc, 
    'LR': lrc, 
    'RF': rfc, 
    'AdaBoost': abc, 
    'BgC': bc, 
    'ETC': etc,
    'GBDT':gbdt,
    'xgb':xgb
}

# %%
svc = SVC()

# %% [markdown]
# - In the above dictonary the key is my algorithm name and values are objects  of that algorithms

# %%
def train_classifier(clf,X_train,y_train,X_test,y_test):
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test,y_pred)
    precision = precision_score(y_test,y_pred)
    
    return accuracy,precision

# %%
train_classifier(svc,X_train,y_train,X_test,y_test)
# Out:
# (0.9777562862669246, 0.9831932773109243)

# %%
import warnings 
warnings.filterwarnings("ignore")
accuracy_scores = []
precision_scores = []

for name,clf in clfs.items():
    
    current_accuracy,current_precision = train_classifier(clf, X_train,y_train,X_test,y_test)
    
    print("For ",name)
    print("Accuracy - ",current_accuracy)
    print("Precision - ",current_precision)
    
    accuracy_scores.append(current_accuracy)
    precision_scores.append(current_precision)
# Out:
# For  SVC
# Accuracy -  0.9787234042553191
# Precision -  0.9603174603174603
# For  KN
# Accuracy -  0.902321083172147
# Precision -  0.9743589743589743
# For  NB
# Accuracy -  0.97678916827853
# Precision -  1.0
# For  DT
# Accuracy -  0.9497098646034816
# Precision -  0.9134615384615384
# For  LR
# Accuracy -  0.9593810444874274
# Precision -  0.9137931034482759
# For  RF
# Accuracy -  0.9700193423597679
# Precision -  0.9819819819819819
# For  AdaBoost
# Accuracy -  0.9700193423597679
# Precision -  0.9212598425196851
# For  BgC
# Accuracy -  0.9738878143133463
# Precision -  0.9236641221374046
# For  ETC
# Accuracy -  0.9729206963249516
# Precision -  0.9661016949152542
# For  GBDT
# Accuracy -  0.9555125725338491
# Precision -  0.9259259259259259
# For  xgb
# Accuracy -  0.9709864603481625
# Precision -  0.9426229508196722

# %% [markdown]
# - In the above code i run a loop over the dictonary take one by one algorithms and train the model
#
# - and store the accuracy and precision as well

# %% [markdown]
# - After did the for loop, what the result coming we convert into a DataFrame

# %%
performance_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy':accuracy_scores,'Precision':precision_scores}).sort_values('Precision',ascending=False)

# %%
performance_df
# Out:
#    Algorithm  Accuracy  Precision
# 2         NB  0.976789   1.000000
# 5         RF  0.970019   0.981982
# 1         KN  0.902321   0.974359
# 8        ETC  0.972921   0.966102
# 0        SVC  0.978723   0.960317
# 10       xgb  0.970986   0.942623
# 9       GBDT  0.955513   0.925926
# 7        BgC  0.973888   0.923664
# 6   AdaBoost  0.970019   0.921260
# 4         LR  0.959381   0.913793
# 3         DT  0.949710   0.913462

# %% [markdown]
# - In the above DataFrame **NB**, **RF**, **SVC** and **ETC** gave the good precesions

# %%
performance_df1 = pd.melt(performance_df, id_vars = "Algorithm")
performance_df1
# Out:
#    Algorithm   variable     value
# 0         NB   Accuracy  0.976789
# 1         RF   Accuracy  0.970019
# 2         KN   Accuracy  0.902321
# 3        ETC   Accuracy  0.972921
# 4        SVC   Accuracy  0.978723
# 5        xgb   Accuracy  0.970986
# 6       GBDT   Accuracy  0.955513
# 7        BgC   Accuracy  0.973888
# 8   AdaBoost   Accuracy  0.970019
# 9         LR   Accuracy  0.959381
# 10        DT   Accuracy  0.949710
# 11        NB  Precision  1.000000
# 12        RF  Precision  0.981982
# 13        KN  Precision  0.974359
# 14       ETC  Precision  0.966102
# 15       SVC  Precision  0.960317
# 16       xgb  Precision  0.942623
# 17      GBDT  Precision  0.925926
# 18       BgC  Precision  0.923664
# 19  AdaBoost  Precision  0.921260
# 20        LR  Precision  0.913793
# 21        DT  Precision  0.913462

# %% [markdown]
# - pd.melt() is used to transform a wide-format DataFrame into a long-format DataFrame
#
# - id_vars="Algorithm":
#
#     - Specifies the column to keep unchanged during the transformation. In this case, the column Algorithm will remain as is and act as an identifier in the reshaped DataFrame. performance_df1:
#
# - This is the resulting DataFrame after applying pd.melt

# %%
sns.catplot(x = 'Algorithm', y='value', 
               hue = 'variable',data=performance_df1, kind='bar',height=5)
plt.ylim(0.5,1.0)
plt.xticks(rotation='vertical')
plt.show()

# %%
# Improve the models
# 1.change the max_feature parameter of Tfdf

# %% [markdown]
# - When we import Tfdf package there will be a hidden max_feature are present.
#
# - when we do vectorize in our tex it will be important how much do vectorize for words

# %%
temp_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy_max_ft_3000':accuracy_scores,'Precision_max_ft_3000':precision_scores}).sort_values('Precision_max_ft_3000',ascending=False)

# %%
performance_df.merge(temp_df,on='Algorithm')
# Out:
#    Algorithm  Accuracy  Precision  Accuracy_max_ft_3000  Precision_max_ft_3000
# 0         NB  0.976789   1.000000              0.976789               1.000000
# 1         RF  0.970019   0.981982              0.970019               0.981982
# 2         KN  0.902321   0.974359              0.902321               0.974359
# 3        ETC  0.972921   0.966102              0.972921               0.966102
# 4        SVC  0.978723   0.960317              0.978723               0.960317
# 5        xgb  0.970986   0.942623              0.970986               0.942623
# 6       GBDT  0.955513   0.925926              0.955513               0.925926
# 7        BgC  0.973888   0.923664              0.973888               0.923664
# 8   AdaBoost  0.970019   0.921260              0.970019               0.921260
# 9         LR  0.959381   0.913793              0.959381               0.913793
# 10        DT  0.949710   0.913462              0.949710               0.913462

# %%
temp_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy_scaling':accuracy_scores,'Precision_scaling':precision_scores}).sort_values('Precision_scaling',ascending=False)

# %%
new_df = performance_df.merge(temp_df,on='Algorithm')
new_df
# Out:
#    Algorithm  Accuracy  Precision  Accuracy_scaling  Precision_scaling
# 0         NB  0.976789   1.000000          0.976789           1.000000
# 1         RF  0.970019   0.981982          0.970019           0.981982
# 2         KN  0.902321   0.974359          0.902321           0.974359
# 3        ETC  0.972921   0.966102          0.972921           0.966102
# 4        SVC  0.978723   0.960317          0.978723           0.960317
# 5        xgb  0.970986   0.942623          0.970986           0.942623
# 6       GBDT  0.955513   0.925926          0.955513           0.925926
# 7        BgC  0.973888   0.923664          0.973888           0.923664
# 8   AdaBoost  0.970019   0.921260          0.970019           0.921260
# 9         LR  0.959381   0.913793          0.959381           0.913793
# 10        DT  0.949710   0.913462          0.949710           0.913462

# %%
new_df_scaled = new_df.merge(temp_df,on='Algorithm')
new_df_scaled
# Out:
#    Algorithm  Accuracy  Precision  Accuracy_scaling_x  Precision_scaling_x  \
# 0         NB  0.976789   1.000000            0.976789             1.000000
# 1         RF  0.970019   0.981982            0.970019             0.981982
# 2         KN  0.902321   0.974359            0.902321             0.974359
# 3        ETC  0.972921   0.966102            0.972921             0.966102
# 4        SVC  0.978723   0.960317            0.978723             0.960317
# 5        xgb  0.970986   0.942623            0.970986             0.942623
# 6       GBDT  0.955513   0.925926            0.955513             0.925926
# 7        BgC  0.973888   0.923664            0.973888             0.923664
# 8   AdaBoost  0.970019   0.921260            0.970019             0.921260
# 9         LR  0.959381   0.913793            0.959381             0.913793
# 10        DT  0.949710   0.913462            0.949710             0.913462
#
#     Accuracy_scaling_y  Precision_scaling_y
# ...

# %%
temp_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy_num_chars':accuracy_scores,'Precision_num_chars':precision_scores}).sort_values('Precision_num_chars',ascending=False)

# %%
new_df_scaled.merge(temp_df,on='Algorithm')
# Out:
#    Algorithm  Accuracy  Precision  Accuracy_scaling_x  Precision_scaling_x  \
# 0         NB  0.976789   1.000000            0.976789             1.000000
# 1         RF  0.970019   0.981982            0.970019             0.981982
# 2         KN  0.902321   0.974359            0.902321             0.974359
# 3        ETC  0.972921   0.966102            0.972921             0.966102
# 4        SVC  0.978723   0.960317            0.978723             0.960317
# 5        xgb  0.970986   0.942623            0.970986             0.942623
# 6       GBDT  0.955513   0.925926            0.955513             0.925926
# 7        BgC  0.973888   0.923664            0.973888             0.923664
# 8   AdaBoost  0.970019   0.921260            0.970019             0.921260
# 9         LR  0.959381   0.913793            0.959381             0.913793
# 10        DT  0.949710   0.913462            0.949710             0.913462
#
#     Accuracy_scaling_y  Precision_scaling_y  Accuracy_num_chars  \
# ...

# %% [markdown]
# **Voting classifiers**

# %%
svc = SVC(kernel='sigmoid', gamma=1.0,probability=True)
mnb = MultinomialNB()
etc = ExtraTreesClassifier(n_estimators=50, random_state=2)

from sklearn.ensemble import VotingClassifier

# %%
mnb = MultinomialNB()
mnb.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
voting = VotingClassifier(estimators=[('svm', svc), ('nb', mnb), ('et', etc)],voting='soft')

# %% [markdown]
# - A voting classifiers is a ML techniques that combines the predictions of multiple models to make final decisions
#
# - It works like group of people voting to make a choice--- the majority wins

# %%
voting.fit(X_train,y_train)
# Out:
# VotingClassifier(estimators=[('svm',
#                               SVC(gamma=1.0, kernel='sigmoid',
#                                   probability=True)),
#                              ('nb', MultinomialNB()),
#                              ('et',
#                               ExtraTreesClassifier(n_estimators=50,
#                                                    random_state=2))],
#                  voting='soft')

# %%
VotingClassifier(estimators=[('svm',
                              SVC(gamma=1.0, kernel='sigmoid',
                                  probability=True)),
                             ('nb', MultinomialNB()),
                             ('et',
                              ExtraTreesClassifier(n_estimators=50,
                                                   random_state=2))],
                 voting='soft')
# Out:
# VotingClassifier(estimators=[('svm',
#                               SVC(gamma=1.0, kernel='sigmoid',
#                                   probability=True)),
#                              ('nb', MultinomialNB()),
#                              ('et',
#                               ExtraTreesClassifier(n_estimators=50,
#                                                    random_state=2))],
#                  voting='soft')

# %%
y_pred = voting.predict(X_test)
print("Accuracy",accuracy_score(y_test,y_pred))
print("Precision",precision_score(y_test,y_pred))
# Out:
# Accuracy 0.9816247582205029
# Precision 0.983739837398374

# %%
# Applying stacking
estimators=[('svm', svc), ('nb', mnb), ('et', etc)]
final_estimator=RandomForestClassifier()

# %%
from sklearn.ensemble import StackingClassifier

# %%
clf = StackingClassifier(estimators=estimators, final_estimator=final_estimator)

# %% [markdown]
# Stacking (or stacked generalization) is another ensemble learning method, but it’s a bit smarter than voting. Instead of just combining the predictions, it uses another model (called a meta-model) to learn how to combine the predictions from different models.

# %%
clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)
print("Accuracy",accuracy_score(y_test,y_pred))
print("Precision",precision_score(y_test,y_pred))
# Out:
# Accuracy 0.9806576402321083
# Precision 0.9538461538461539

# %% [markdown]
# - at the end we decide that we goes through the **multinomial naive bais**

# %% [markdown]
# - Now we create a pipe line and convert that pipeline intoa website

# %%
# steps if a email came
# transform the text
# vectorise
# apply algorithms

# %%
import pickle
pickle.dump(tf,open('vectorizer.pkl', 'wb'))
pickle.dump(mnb,open('model.pkl','wb'))
